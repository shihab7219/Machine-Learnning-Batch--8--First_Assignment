# %%
# importing Impotent Modules 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Read Csv Data file

data = pd.read_csv("Height-Weight Data.csv")
print(data)
data.head(10)
#data.size()
data.shape
# Out:
#          Height      Weight
# 0     73.847017  241.893563
# 1     68.781904  162.310473
# 2     74.110105  212.740856
# 3     71.730978  220.042470
# 4     69.881796  206.349801
# ...         ...         ...
# 3496  69.296830  185.649086
# 3497  70.542201  210.198845
# 3498  73.912549  202.429960
# 3499  67.396021  144.277671
# 3500  72.738970  187.222909
#
# [3501 rows x 2 columns]
# (3501, 2)

# %%
data["Height"]
#data.Height
# Out:
# 0       73.847017
# 1       68.781904
# 2       74.110105
# 3       71.730978
# 4       69.881796
#           ...
# 3496    69.296830
# 3497    70.542201
# 3498    73.912549
# 3499    67.396021
# 3500    72.738970
# Name: Height, Length: 3501, dtype: float64

# %%
data.Weight
# Out:
# 0       241.893563
# 1       162.310473
# 2       212.740856
# 3       220.042470
# 4       206.349801
#            ...
# 3496    185.649086
# 3497    210.198845
# 3498    202.429960
# 3499    144.277671
# 3500    187.222909
# Name: Weight, Length: 3501, dtype: float64

# %%
#plot this data

plt.scatter(data.Height,data.Weight, marker = "*", color = "green")

# %%
plot_data = plt.scatter(data.Height,data.Weight , marker = "+", color = "blue")
plt.xlabel("Height")
plt.ylabel("Weight")
#plt.title("")
print(plot_data)

# %%
#Data training and testing 

from sklearn.model_selection import train_test_split

# %%
Height = data[["Height"]]
Weight = data["Weight"]

# %%
#Height_train , Weight_train,Height_test,Weight_test = train_test_split(Height,Weight, test_size = .35, random_state = 1)
Height_train,Height_test ,Weight_train,Weight_test = train_test_split(Height,Weight, test_size = .30, random_state = 1)

# %%
Height_train
# Out:
#          Height
# 221   66.786927
# 2696  65.192862
# 1334  68.390109
# 3402  68.145621
# 1159  71.647580
# ...         ...
# 2763  68.457061
# 905   66.539812
# 1096  75.999957
# 235   70.555244
# 1061  70.269360
#
# [2450 rows x 1 columns]

# %%
Height_test
# Out:
#          Height
# 719   67.402821
# 2296  69.560033
# 3083  65.809912
# 1296  67.687531
# 2234  65.077902
# ...         ...
# 236   69.867101
# 1125  70.280692
# 1008  72.837685
# 2169  67.675148
# 270   72.049890
#
# [1051 rows x 1 columns]

# %%
Weight_train
# Out:
# 221     165.431242
# 2696    185.348211
# 1334    179.352182
# 3402    197.476930
# 1159    200.286509
#            ...
# 2763    186.208566
# 905     175.093255
# 1096    224.440459
# 235     198.460249
# 1061    192.307027
# Name: Weight, Length: 2450, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
Train_Data= LinearRegression()

# %%
#r.fit(Height_train , Weight_train)
Train_Data.fit(Height_train,Weight_train)
# Out:
# LinearRegression()

# %%
Train_Data.fit(Height_train,Weight_train)
# Out:
# LinearRegression()

# %%
Train_Data.predict([[68.78190405]])
# Out:
# array([185.31432533])

# %%
Weight.head()
# Out:
# 0    241.893563
# 1    162.310473
# 2    212.740856
# 3    220.042470
# 4    206.349801
# Name: Weight, dtype: float64

# %%
Weight_train
# Out:
# 221     165.431242
# 2696    185.348211
# 1334    179.352182
# 3402    197.476930
# 1159    200.286509
#            ...
# 2763    186.208566
# 905     175.093255
# 1096    224.440459
# 235     198.460249
# 1061    192.307027
# Name: Weight, Length: 2450, dtype: float64

# %%
Height_train.shape
# Out:
# (2450, 1)

# %%
M = Train_Data.coef_
M
# Out:
# array([5.97744946])

# %%
C = Train_Data.intercept_
C
# Out:
# -225.82603000755844

# %%
y = (M*68.78190405)+C
y
# Out:
# array([185.31432533])

# %%
data["Predicted Weight"] = Train_Data.predict(Height)
data.tail()
# Out:
#          Height      Weight  Predicted Weight
# 3496  69.296830  185.649086        188.392269
# 3497  70.542201  210.198845        195.836414
# 3498  73.912549  202.429960        215.982497
# 3499  67.396021  144.277671        177.030278
# 3500  72.738970  187.222909        208.967487

# %%
data
# Out:
#          Height      Weight  Predicted Weight
# 0     73.847017  241.893563        215.590782
# 1     68.781904  162.310473        185.314325
# 2     74.110105  212.740856        217.163380
# 3     71.730978  220.042470        202.942268
# 4     69.881796  206.349801        191.888873
# ...         ...         ...               ...
# 3496  69.296830  185.649086        188.392269
# 3497  70.542201  210.198845        195.836414
# 3498  73.912549  202.429960        215.982497
# 3499  67.396021  144.277671        177.030278
# 3500  72.738970  187.222909        208.967487
#
# [3501 rows x 3 columns]

# %%
plt.scatter(data.Height,data.Weight, marker = "+", color = "red")

plt.xlabel("Height Data")
plt.ylabel("Weight Data")

plt.plot(data.Height,data["Predicted Weight"])
plt.scatter(data.Height,data["Predicted Weight"], marker= "*", color = "green" )
